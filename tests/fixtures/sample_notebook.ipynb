# %% [markdown]
# # First Principles Analysis of k-Nearest Neighbors
#
# This notebook explores k-NN from fundamental principles.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## First Principle: Distance Represents Similarity
#
# The fundamental assumption of k-NN is that similar items are close together in feature space.

# %%
# Simple plot
plt.plot([1, 2, 3], [1, 4, 9])
plt.title('Sample Plot')
plt.show()
